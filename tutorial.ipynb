# %% [markdown]
# # Autenticação na API

# %% [markdown]
# ## instalação da lib

# %%
# !pip install requests_oauthlib --force-reinstall

# %% [markdown]
# ## Etapa de autorização

# %%
import requests
from requests_oauthlib import OAuth2Session

# Dados da aplicação registrada no GitHub
client_id = "Ov23liTFpiWL4zMuc5Tx"
client_secret = "e1494122a9f7dbf97e3659dd48f609ba961a56f1"
redirect_uri = "https://mle-tech-chalenge-1.onrender.com/callback"


# URLs do GitHub
authorization_base_url = "https://github.com/login/oauth/authorize"
token_url = "https://github.com/login/oauth/access_token"


# Criar sessão OAuth2
github = OAuth2Session(client_id, redirect_uri=redirect_uri)

# Passo 1: Obter URL de autorização
authorization_url, state = github.authorization_url(authorization_base_url)
print("Acesse este link para autorizar:", authorization_url)
## Refaça esse passo na mesma aba da primeira vez para que o callback esteja unitilizado e funcione corretamente.
# Out:
# Acesse este link para autorizar: https://github.com/login/oauth/authorize?response_type=code&client_id=Ov23liTFpiWL4zMuc5Tx&redirect_uri=https%3A%2F%2Fmle-tech-chalenge-1.onrender.com%2Fcallback&state=L3QXDVNaZNpXEndsbMNGr9eQXW3Lmu

# %%
# Depois da segunda execução, acesse a ferramenta DevTools do navegador para copiar o URL de redirecionamento completo que é a callback****
# Cole o URL de redirecionamento completo em redirect_response
redirect_response = "https://mle-tech-chalenge-1.onrender.com/callback/?code=88a0f15c4c658edb5a29&state=L3QXDVNaZNpXEndsbMNGr9eQXW3Lmu"

# Passo 2: Trocar o código pelo token de acesso
token = github.fetch_token(
    token_url,
    client_secret=client_secret,
    authorization_response=redirect_response
)

print("Token de acesso:", token)
# Out:
# Token de acesso: {'access_token': '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', 'token_type': 'bearer', 'scope': ['user:email']}

# %% [markdown]
# # Obter as estatisticas dos livros e das categorias

# %%
response = github.get("https://mle-tech-chalenge-1.onrender.com/api/v1/stats/overview", )
print(response.json())
# Out:
# {'total_books': 1000.0, 'avg_price': 35.07034999999999, 'avg_rating': 2.923, 'distribution_rating': {'1': 226, '2': 196, '3': 203, '4': 179, '5': 196}}

# %%
response = github.get("https://mle-tech-chalenge-1.onrender.com/api/v1/stats/categories", )
print(response.json())
# Out:
# [{'category': 'Academic', 'total_books': 1, 'avg_price': 13.12}, {'category': 'Add a comment', 'total_books': 67, 'avg_price': 35.8}, {'category': 'Adult Fiction', 'total_books': 1, 'avg_price': 15.36}, {'category': 'Art', 'total_books': 8, 'avg_price': 38.52}, {'category': 'Autobiography', 'total_books': 9, 'avg_price': 37.05}, {'category': 'Biography', 'total_books': 5, 'avg_price': 33.66}, {'category': 'Business', 'total_books': 12, 'avg_price': 32.46}, {'category': 'Childrens', 'total_books': 29, 'avg_price': 32.64}, {'category': 'Christian', 'total_books': 3, 'avg_price': 42.5}, {'category': 'Christian Fiction', 'total_books': 6, 'avg_price': 34.38}, {'category': 'Classics', 'total_books': 19, 'avg_price': 36.55}, {'category': 'Contemporary', 'total_books': 3, 'avg_price': 36.2}, {'category': 'Crime', 'total_books': 1, 'avg_price': 10.97}, {'category': 'Cultural', 'total_books': 1, 'avg_price': 36.58}, {'category': 'Default', 'total_books': 152, 'avg_price': 34.39}, {'category':
# ...

# %% [markdown]
# # Obter as features para um modelo

# %%
response = github.get("https://mle-tech-chalenge-1.onrender.com/api/v1/ml/features", )
print(response.json())

# %% [markdown]
# # Obter os dados de treinamento

# %%
response = github.get("https://mle-tech-chalenge-1.onrender.com/api/v1/ml/data_training", )
print(response.json())

# %% [markdown]
# É nessa etapa que o  cientista, ao obter o dado de treinamento selecionaria o alvo e então partiria para o treinamento do modelo mais adequado. Ao escolher o melhor modelo, com as melhores métricas e hiperparâmetros ele empacotaria usando pickle por exemplo e então armazenaria ele para ser usado dentro da rota de predições

# %% [markdown]
# # Enviar as predições

# %%
url = "https://mle-tech-chalenge-1.onrender.com/api/v1/ml/predictions" 
payload = { "features": { "rating": 4.5, "price": 29.99, "number_of_reviews": 150, "category_id": 1, "availability": 50 } } 
response = github.post(url, json=payload) 
print("Resposta:", response.json())
